# %%
! pip install python-dotenv
! pip install pydub
! pip install pandas
! pip install psycopg2
! pip install google-auth google-auth-httplib2 google-api-python-client google-auth-oauthlib
! pip install tqdm
! pip install pytube

# %%
import pandas as pd

# %%
import sys

sys.path.append('../util')

from util import read_spreadsheet

# %%
df = read_spreadsheet(sheet_id="1yKSzConuVWo8BuMDs2mabF5iiBKUz2wF--LIabFN6QE")

# %%
df.head()
# Out:
#    Sr. No          ID                                      YouTube link  \
# 0       1  STT_HS0001  https://youtu.be/HorznIZUGOY?si=GRHxy-0rcElboMlO
# 1       2  STT_HS0002  https://youtu.be/yk4MoBjSZWs?si=5aUTcv2bO_OWpoJu
# 2       3  STT_HS0003  https://youtu.be/dmqh2T7HoF4?si=EEj4MXtz8qcMS5VY
# 3       4  STT_HS0004  https://youtu.be/ZHYflNTXleU?si=MIFuEbPIX45RwtHD
# 4       5  STT_HS0005  https://youtu.be/XyjBVj6GZ88?si=x_DArqp0-eQaeKqG
#
#    Duration Publishing Year             Name  Gender Age  Group ཐོབ་ཁོངས།  \
# 0  38:00:00   April 7, 2010           Tendol  Female      70-80    Utsang
# 1  55:46:00  April 13, 2010            Dekyi  Female      60-70    Utsang
# 2  42:30:00    May 20, 2012    Tsering Norbu    Male      70-80    Utsang
# 3  53:43:00    May 23, 2012  Kunchok (alias)    Male      80-90    Utsang
# 4  59:28:00   June 27, 2007   Dorji Phuntsok    Male      80-90    Utsang
#
#    བཙན་བྱོལ་དུ་འབྱོར་ལོ།           Group Uploaded
# 0                 1959.0  A Tenzin Nyima     True
# 1                 1961.0  A Tenzin Nyima     True
# 2                 1959.0  A Tenzin Nyima     True
# 3                 1959.0  A Tenzin Nyima     True
# 4                 1959.0  A Tenzin Nyima     True

# %%
import pandas as pd
from pytube import YouTube

# Function to get video duration from a youtube video URL
def get_video_duration(url):
    try:
        yt = YouTube(url)
        duration = yt.length  # Duration in seconds
        duration = pd.to_datetime(duration, unit='s').strftime('%H:%M:%S')  # Duration in
        return duration
    except Exception as e:
        print(f"Error fetching duration for {url}: {e}")
        return None

# %%
# Apply the function to the DataFrame
df['standard duration'] = df['Audio link'].apply(get_video_duration)
# Out:
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0006_01/H_0006_01.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0006_02/H_0006_02.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0000_01/H_0000_01.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0000_02/H_0000_02.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0000_03/H_0000_03.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0000_04/H_0000_04.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0000_05/H_0000_05.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0000_06/H_0000_06.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0000_07/H_0000_07.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0001_01/H_0001_01.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0001_02/H_0001_02.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0001_03/H_0001_03.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0001_04/H_0001_04.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0001_05/H_0001_05.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0001_06/H_0001_06.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0001_07/H_0001_07.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0001_08/H_0001_08.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0001_09/H_0001_09.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0001_10/H_0001_10.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0001_11/H_0001_11.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0001_12/H_0001_12.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0001_13/H_0001_13.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0001_14/H_0001_14.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0001_15/H_0001_15.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0002_01/H_0002_01.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0002_02/H_0002_02.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0002_03/H_0002_03.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0002_04/H_0002_04.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0004_01/H_0004_01.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0004_02/H_0004_02.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0004_03/H_0004_03.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0004_04/H_0004_04.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0004_05/H_0004_05.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0004_06/H_0004_06.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0004_07/H_0004_07.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0004_08/H_0004_08.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0004_09/H_0004_09.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0004_10/H_0004_10.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0004_11/H_0004_11.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_0004_12/H_0004_12.mp3: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://tile.loc.gov/storage-services/service/asian/asiantoha/H_