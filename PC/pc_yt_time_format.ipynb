# %%
! pip install python-dotenv
! pip install pydub
! pip install pandas
! pip install psycopg2
! pip install google-auth google-auth-httplib2 google-api-python-client google-auth-oauthlib
! pip install tqdm
! pip install pytube
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: python-dotenv in /home/gangagyatso/.local/lib/python3.10/site-packages (1.0.1)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pydub in /home/gangagyatso/.local/lib/python3.10/site-packages (0.25.1)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/gangagyatso/.local/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /home/gangagyatso/.local/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/gangagyatso/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/gangagyatso/.local/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: psycopg2 in /home/gangagyatso/.local/lib/python3.10/site-packages (2.9.9)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: google-auth in /home/gangagyatso/.local/lib/python3.10/site-packages (2.23.2)
# Requirement already satisfied: google-auth-httplib2 in /home/gangagyatso/.local/lib/python3.10/site-packages (0.1.1)
# Requirement already satisfied: google-api-python-client in /home/gangagyatso/.local/lib/python3.10/site-packages (2.102.0)
# Requirement already satisfied: google-auth-oauthlib in /home/gangagyatso/.local/lib/python3.10/site-packages (1.2.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/gangagyatso/.local/lib/python3.10/site-packages (from google-auth) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/gangagyatso/.local/lib/python3.10/site-packages (from google-auth) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/gangagyatso/.local/lib/python3.10/site-packages (from google-auth) (4.9)
# Requirement already satisfied: httplib2>=0.19.0 in /usr/lib/python3/dist-packages (from google-auth-httplib2) (0.20.2)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /home/gangagyatso/.local/lib/python3.10/site-packages (from google-api-python-client) (2.12.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /home/gangagyatso/.local/lib/python3.10/site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/gangagyatso/.local/lib/python3.10/site-packages (from google-auth-oauthlib) (2.0.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /home/gangagyatso/.local/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.60.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /home/gangagyatso/.local/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (4.24.4)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /home/gangagyatso/.local/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.32.3)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/lib/python3/dist-packages (from httplib2>=0.19.0->google-auth-httplib2) (2.4.7)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/gangagyatso/.local/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/gangagyatso/.local/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/gangagyatso/.local/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2020.6.20)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tqdm in /home/gangagyatso/.local/lib/python3.10/site-packages (4.66.1)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pytube in /home/gangagyatso/.local/lib/python3.10/site-packages (15.0.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd

# %%
import sys

sys.path.append('../util')

from util import read_spreadsheet

# %%
df = read_spreadsheet(sheet_id="1wJ2tPcTec_KnIaN0qcn5fOhBGMzYSHBXmv3kgHYVPlg")

# %%
df.head()
# Out:
#    no          ID                                    Name of podcast  \
# 0   1  STT_PC0001                         Episode-13 | Language Guru
# 1   2  STT_PC0002  Dr. Thupten Jinpa | Scholar | Principal Englis...
# 2   3  STT_PC0003  Geshe Lhakdor la: Library Tour and Personal Jo...
# 3   4  STT_PC0004  Ama Metok Yangchen |Mompreneur | Community Worker
# 4   5  STT_PC0005                              Sikyong Penpa Tsering
#
#                                        YouTube link  Publishing year  \
# 0                      https://youtu.be/ZLxJxJ3pki8           2022.0
# 1  https://youtu.be/HHZ6NyeBvV0?si=olp5eqEAx--RWX3H           2024.0
# 2  https://youtu.be/7dhuhRGAOyg?si=mej3Tz6bGsuCEANI           2023.0
# 3  https://youtu.be/hfE5Mvrb5mI?si=ijJMyErbcktmPhoT           2023.0
# 4  https://youtu.be/h0S_1bXgFVE?si=-540QLt8TCCh5fj3           2022.0
#
#          Channel Auidio Quality Country  Gender Age Group  uploaded
# 0  Bhuchung Kata           Good   India    Male     30-40      True
# 1  Bhuchung Kata           Good   India    Male     60-70      True
# 2  Bhuchung Kata           Good   India    Male     60-70      True
# 3  Bhuchung Kata           Good   India  Female     60-70      True
# 4  Bhuchung Kata           Good   India    Male     50-60      True

# %%
import pandas as pd
from pytube import YouTube

# Function to get video duration from a youtube video URL
def get_video_duration(url):
    try:
        yt = YouTube(url)
        duration = yt.length  # Duration in seconds
        duration = pd.to_datetime(duration, unit='s').strftime('%H:%M:%S')  # Duration in
        return duration
    except Exception as e:
        print(f"Error fetching duration for {url}: {e}")
        return None

# %%
# Apply the function to the DataFrame
df['standard duration'] = df['YouTube link'].apply(get_video_duration)
# Out:
# Error fetching duration for eyes of Tibet: regex_search: could not find match for (?:v=|\/)([0-9A-Za-z_-]{11}).*
# Error fetching duration for https://www.youtube.com/watch?v=oq_O-zvfMDU: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://youtu.be/_vfDvi1i7q4?si=CJfG_SnvlxDCtmwU: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://youtu.be/bDLGYcxPzlA?si=7_aM_w3K8YFHt6xp: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://youtu.be/OUZoDRxcYME?si=1CoT3B6LGGsU7MxV: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://youtu.be/hznms6ofF74?si=NqwFQul2Z6FocNQo: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://youtu.be/pdX7A_hLlDI?si=Q4IvYc87oooC1IUm: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for https://youtu.be/e50DHI6FyUU?si=AG4mEeqjDilhShJQ: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object
# Error fetching duration for nan: expected string or bytes-like object

# %%
df['standard duration'].to_csv('pc_yt_standard_duration.csv', index=False)

# %%
df.to_csv('pc_yT.csv', index=False)
