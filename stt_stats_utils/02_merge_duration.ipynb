# %%
import sys
sys.path.append('../util')

from util import read_spreadsheet

# %%
#NW DEPARTMENT
df = read_spreadsheet(sheet_id="1U6Bm7mx1XpbgvHzXlxGv_BQR-bhBern5")

# %%
df.columns
# Out:
# Index(['no', 'ID', 'Name of podcast', 'YouTube link', 'standard duration',
#        'Publishing year', 'Channel', 'Auidio Quality', 'Country', 'Gender',
#        'Age Group', 'Uploaded', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26'],
#       dtype='object')

# %%
duration = df['standard duration']

# %%
df['standard duration'].to_csv('duration.csv', index=False)

# %%
import pandas as pd
# Function to convert HH:MM:SS.mmm to total seconds
def convert_to_seconds(time_str):
    if pd.isna(time_str) or not str(time_str).strip(): 
        print(time_str)  # Check for NaN, None, or empty string
        return 0  # Treat empty or NaN time as 0 seconds
    
    # Split the time string into hours, minutes, and seconds.milliseconds
    h, m, s = str(time_str).split(':')
    
    # Further split the seconds part to separate seconds and milliseconds
    s, ms = map(float, s.split('.')) if '.' in s else (int(s), 0.0)
    
    # Convert hours, minutes, and seconds to total seconds
    return int(h) * 3600 + int(m) * 60 + s + ms / 1000

# %%
# Convert all time durations to seconds and sum them
total_seconds = sum(convert_to_seconds(td) for td in duration)

hours = int(total_seconds // 3600)
minutes = int((total_seconds % 3600) // 60)
seconds = total_seconds % 60

# Format the result as HH:MM:SS
total_duration_str = f"{hours:02}:{minutes:02}:{seconds:02}"

print(f"Total Duration: {total_duration_str}")
# Out:
# nan
# nan
# Total Duration: 184:01:54.0

# %%
df1 = df

# %%
df1.columns
# Out:
# Index(['no', 'ID', 'Name of podcast', 'YouTube link', 'standard duration',
#        'Publishing year', 'Channel', 'Auidio Quality', 'Country', 'Gender',
#        'Age Group', 'Uploaded', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26'],
#       dtype='object')

# %%
df2 = pd.read_csv("dept_files/STT_PC.csv")

# %%
df2.columns
# Out:
# Index(['ID', 'split duration', 'dept'], dtype='object')

# %%
df2.head()
# Out:
#            ID split duration    dept
# 0  STT_PC0001   00:22:52.003  STT_PC
# 1  STT_PC0002   01:33:39.116  STT_PC
# 2  STT_PC0003   00:45:11.350  STT_PC
# 3  STT_PC0004   00:34:00.754  STT_PC
# 4  STT_PC0005   00:26:15.996  STT_PC

# %%
merged_df = pd.merge(df1, df2, on='ID', how='left')

# %%
merged_df.head()
# Out:
#     no          ID                                    Name of podcast  \
# 0  1.0  STT_PC0001                         Episode-13 | Language Guru
# 1  2.0  STT_PC0002  Dr. Thupten Jinpa | Scholar | Principal Englis...
# 2  3.0  STT_PC0003  Geshe Lhakdor la: Library Tour and Personal Jo...
# 3  4.0  STT_PC0004  Ama Metok Yangchen |Mompreneur | Community Worker
# 4  5.0  STT_PC0005                              Sikyong Penpa Tsering
#
#                                        YouTube link standard duration  \
# 0                      https://youtu.be/ZLxJxJ3pki8          00:33:53
# 1  https://youtu.be/HHZ6NyeBvV0?si=olp5eqEAx--RWX3H          01:39:44
# 2  https://youtu.be/7dhuhRGAOyg?si=mej3Tz6bGsuCEANI          01:12:46
# 3  https://youtu.be/hfE5Mvrb5mI?si=ijJMyErbcktmPhoT          00:59:04
# 4  https://youtu.be/h0S_1bXgFVE?si=-540QLt8TCCh5fj3          00:35:43
#
#   Publishing year        Channel Auidio Quality Country  Gender  ...  \
# 0            2022  Bhuchung Kata           Good   India    Male  ...
# 1            2024  Bhuchung Kata           Good   India    Male  ...
# 2            2023  Bhuchung Kata           Good   India    Male  ...
# 3            2023  Bhuchung Kata           Good   India  Female  ...
# 4            2022  Bhuchung Kata           Good   India    Male  ...
#
#   Unnamed: 19 Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  \
# 0         NaN         NaN          NaN          NaN          NaN          NaN
# 1         NaN         NaN          NaN          NaN          NaN          NaN
# 2         NaN         NaN          NaN          NaN          NaN          NaN
# 3         NaN         NaN          NaN          NaN          NaN          NaN
# 4         NaN         NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 25  Unnamed: 26  split duration    dept
# 0          NaN          NaN    00:22:52.003  STT_PC
# 1          NaN          NaN    01:33:39.116  STT_PC
# 2          NaN          NaN    00:45:11.350  STT_PC
# 3          NaN          NaN    00:34:00.754  STT_PC
# 4          NaN          NaN    00:26:15.996  STT_PC
#
# [5 rows x 29 columns]

# %%
merged_df.columns
# Out:
# Index(['no', 'ID', 'Name of podcast', 'YouTube link', 'standard duration',
#        'Publishing year', 'Channel', 'Auidio Quality', 'Country', 'Gender',
#        'Age Group', 'Uploaded', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
#        'split duration', 'dept'],
#       dtype='object')

# %%
# Correct way to select specific columns
split_df = merged_df[['ID', 'standard duration', 'split duration', 'Uploaded']]

# %%
split_df.head()
# Out:
#            ID standard duration split duration Uploaded
# 0  STT_PC0001          00:33:53   00:22:52.003     True
# 1  STT_PC0002          01:39:44   01:33:39.116     True
# 2  STT_PC0003          01:12:46   00:45:11.350     True
# 3  STT_PC0004          00:59:04   00:34:00.754     True
# 4  STT_PC0005          00:35:43   00:26:15.996     True

# %%
split_df.to_csv("merged_data/STT_PC.csv", index=False)

# %%
from datetime import datetime, timedelta    
def subtract_durations(row):
    if pd.isna(row['split duration']):
        return ''
    else:
        # Convert to datetime objects1SjlnWsr6YVhBIW6EaS0ITmboDmEuj2VnxGRNL50OPx4
        fmt = '%H:%M:%S.%f' if '.' in row['split duration'] else '%H:%M:%S'
        
        # Convert to datetime.time objects
        standard_time = datetime.strptime(row['standard duration'], '%H:%M:%S').time()
        split_time = datetime.strptime(row['split duration'], fmt).time()
        
        # Combine time with a base date to perform subtraction
        base_date = datetime(2000, 1, 1)  # Arbitrary base date
        standard_datetime = datetime.combine(base_date, standard_time)
        split_datetime = datetime.combine(base_date, split_time)
        
        # Calculate remaining duration
        remaining_time = standard_datetime - split_datetime
        if remaining_time < timedelta(0):
            print(f"Negative time difference: {remaining_time}", row['ID'])
            # If negative, adjust by adding one day
            remaining_time = timedelta(0)
        
        # Convert remaining time to hh:mm:ss format
        remaining_hours, remainder = divmod(remaining_time.seconds, 3600)
        remaining_minutes, remaining_seconds = divmod(remainder, 60)
        
        return f"{remaining_hours:02}:{remaining_minutes:02}:{remaining_seconds:02}"

# %%
split_df['remaining_duration'] = split_df.apply(subtract_durations, axis=1)
# Out:
# Negative time difference: -1 day, 23:36:23.832000 STT_PC0153
# Negative time difference: -1 day, 23:37:08.133000 STT_PC0154
# Negative time difference: -1 day, 23:39:34.019000 STT_PC0155
# Negative time difference: -1 day, 23:39:11.357000 STT_PC0156
# Negative time difference: -1 day, 23:36:54.885000 STT_PC0157
# Negative time difference: -1 day, 23:55:04.406000 STT_PC0158
# Negative time difference: -1 day, 23:46:10.339000 STT_PC0219
# Negative time difference: -1 day, 23:23:37.418000 STT_PC0221
# Negative time difference: -1 day, 23:41:59.996000 STT_PC0222
# Negative time difference: -1 day, 23:54:02.897000 STT_PC0223
# Negative time difference: -1 day, 23:47:00.077000 STT_PC0224
# Negative time difference: -1 day, 23:29:08.269000 STT_PC0225
# Negative time difference: -1 day, 23:56:49.936000 STT_PC0228
# Negative time difference: -1 day, 23:55:24.283000 STT_PC0230
# Negative time difference: -1 day, 23:26:54.865000 STT_PC0231
# Negative time difference: -1 day, 23:30:48.260000 STT_PC0232
# Negative time difference: -1 day, 23:58:50.239000 STT_PC0234
# Negative time difference: -1 day, 23:58:46.766000 STT_PC0235
# Negative time difference: -1 day, 23:37:51.449000 STT_PC0237
# Negative time difference: -1 day, 23:36:23.295000 STT_PC0238
# Negative time difference: -1 day, 23:18:50.722000 STT_PC0239
# Negative time difference: -1 day, 22:27:36.938000 STT_PC0240
# Negative time difference: -1 day, 23:36:58.781000 STT_PC0241
# Negative time difference: -1 day, 23:39:54.444000 STT_PC0242
# Negative time difference: -1 day, 23:28:57.195000 STT_PC0243
# Negative time difference: -1 day, 23:27:57.450000 STT_PC0244
# Negative time difference: -1 day, 23:28:02.130000 STT_PC0245
# Negative time difference: -1 day, 23:28:53.399000 STT_PC0246
# Negative time difference: -1 day, 23:41:44.095000 STT_PC0247
# Negative time difference: -1 day, 23:52:59.458000 STT_PC0248
# /tmp/ipykernel_120070/931639638.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['remaining_duration'] = split_df.apply(subtract_durations, axis=1)

# %%
final_df = split_df[['ID', 'standard duration', 'split duration',  'Uploaded', 'remaining_duration']]

# %%
final_df.to_csv("merged_data/STT_PC.csv", index=False)

# %%
split_duration = final_df['split duration']

# %%
#Convert all time durations to seconds and sum them
total_seconds = sum(convert_to_seconds(td) for td in split_duration if td)

# Convert the total seconds back to HH:MM:SS format
hours = int(total_seconds // 3600)
minutes = int((total_seconds % 3600) // 60)
seconds = total_seconds % 60
# Format the result as HH:MM:SS
total_duration_str = f"{hours:02}:{minutes:02}:{seconds:02}"

print(f"Total split Duration: {total_duration_str}")
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Total split Duration: 81:52:40.182999999960884

# %%
loss_duration = final_df['remaining_duration']

# %%
#Convert all time durations to seconds and sum them
total_seconds = sum(convert_to_seconds(td) for td in loss_duration if td)

# Convert the total seconds back to HH:MM:SS format
hours = int(total_seconds // 3600)
minutes = int((total_seconds % 3600) // 60)
seconds = total_seconds % 60
# Format the result as HH:MM:SS
total_duration_str = f"{hours:02}:{minutes:02}:{seconds:02}"

print(f"Total loss Duration: {total_duration_str}")
# Out:
# Total loss Duration: 57:34:22.0

# %%
total_uploaded_duration_seconds = sum(
    convert_to_seconds(row['standard duration']) 
    for _, row in final_df.iterrows() 
    if pd.notna(row['split duration']) and str(row['split duration']).strip()
)

# Convert total seconds back to HH:MM:SS format
total_hours, remainder = divmod(total_uploaded_duration_seconds, 3600)
total_minutes, total_seconds = divmod(remainder, 60)

total_uploaded_duration = f"{int(total_hours):02}:{int(total_minutes):02}:{int(total_seconds):02}"

print("Total Uploaded Duration:", total_uploaded_duration)
# Out:
# Total Uploaded Duration: 128:09:15

# %%
# Calculate total uploaded duration for rows where 'Pecha Tools' is 'uploaded'
total_uploaded_duration_seconds = sum(
    convert_to_seconds(row['standard duration']) 
    for _, row in final_df.iterrows() 
    if  row['Uploaded'] == True
)

# Convert total seconds back to HH:MM:SS format
total_hours, remainder = divmod(total_uploaded_duration_seconds, 3600)
total_minutes, total_seconds = divmod(remainder, 60)

total_uploaded_duration = f"{int(total_hours):02}:{int(total_minutes):02}:{int(total_seconds):02}"

print("Total Uploaded Duration:", total_uploaded_duration)
# Out:
# Total Uploaded Duration: 116:54:56

# %%
all_split_df = pd.read_csv("dept_files/STT_PC.csv")

# %%
total_uploaded_duration_seconds = sum(
    convert_to_seconds(row['split duration']) 
    for _, row in all_split_df.iterrows() 
)

# Convert total seconds back to HH:MM:SS format
total_hours, remainder = divmod(total_uploaded_duration_seconds, 3600)
total_minutes, total_seconds = divmod(remainder, 60)

total_uploaded_duration = f"{int(total_hours):02}:{int(total_minutes):02}:{int(total_seconds):02}"

print("Total after split Duration:", total_uploaded_duration)
# Out:
# Total after split Duration: 81:52:40

# %%
import matplotlib.pyplot as plt

# Data
departments = ['NS', 'TT', 'CS', 'MV', 'AB', 'PC', 'HS', 'NW']
original_durations = ['462:20:00', '583:26:05', '451:48:12', '557:38:40', '318:10:13', '128:09:15', '252:47:49', '147:16:32']
after_split_durations = ['275:10:19', '344:15:35', '254:55:11', '443:16:18', '232:19:28', '81:52:40', '146:07:29', '115:56:48']
audio_loss_durations = ['188:27:00', '239:49:56', '196:53:01', '118:22:31', '85:50:45', '57:34:22', '106:38:27', '31:14:39']

# Function to convert hh:mm:ss to seconds
def time_to_seconds(t):
    h, m, s = map(int, t.split(':'))
    return h * 3600 + m * 60 + s

# Setting up subplots
fig, axs = plt.subplots(2, 4, figsize=(20, 10))  # 2 rows, 4 columns

for i, ax in enumerate(axs.flat):
    sizes = [time_to_seconds(after_split_durations[i]), time_to_seconds(audio_loss_durations[i])]
    labels = ['After Split Audio', 'Audio Loss']
    colors = ['#66b3ff', '#ff6666']
    
    ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, colors=colors)
    ax.set_title(f'{departments[i]} - Original: {original_durations[i]}')
    ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Adjust layout to prevent overlap
plt.tight_layout()

# Display all pie charts
plt.show()
